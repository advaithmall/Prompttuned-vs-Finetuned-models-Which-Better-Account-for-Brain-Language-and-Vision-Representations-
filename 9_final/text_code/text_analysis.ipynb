# %%
import numpy as np

# %%
import os
print(os.getcwd())
# Out:
# /home2/advaith.malladi

# %%
path = "./csai_a5/scores"
# chdir to the path
os.chdir(path)
print(os.getcwd())
# Out:
# /home2/advaith.malladi/csai_a5/scores

# %%
# print subdirs of current dir
print(os.listdir())
# Out:
# ['pt_subj2_encoding_scores.json', 'ft_subj1_decoding_scores.json', 'vision', 'pt_subj1_encoding_scores.json', 'ft_subj2_decoding_scores.json', 'prompt-tuning-scores', 'pt_subj2_decoding_scores.json', 'ft_subj2_encoding_scores.json', 'pt_subj1_decoding_scores.json', 'ft_subj1_encoding_scores.json']

# %%
pt_subj2_encoding_scores = {}
import json
# load the pt_subj2_encoding_scores.json into above dict
file1 = "ft_subj2_encoding_scores.json"
with open(file1, 'r') as f:
    ft_subj2_encoding_scores = json.load(f)
file1 = "ft_subj1_decoding_scores.json"
ft_subj1_decoding_scores = {}
with open(file1, 'r') as f:
    ft_subj1_decoding_scores = json.load(f)
file1 = "ft_subj2_decoding_scores.json"
ft_subj2_decoding_scores = {}
with open(file1, 'r') as f:
    ft_subj2_decoding_scores = json.load(f)
file1 = "ft_subj1_encoding_scores.json"
ft_subj1_encoding_scores = {}
with open(file1, 'r') as f:
    ft_subj1_encoding_scores = json.load(f)

# %%
file1 = "pt_subj2_encoding_scores.json"
with open(file1, 'r') as f:
    pt_subj2_encoding_scores = json.load(f)
file1 = "pt_subj1_decoding_scores.json"
pt_subj1_decoding_scores = {}
with open(file1, 'r') as f:
    pt_subj1_decoding_scores = json.load(f)
file1 = "pt_subj2_decoding_scores.json"
pt_subj2_decoding_scores = {}
with open(file1, 'r') as f:
    pt_subj2_decoding_scores = json.load(f)
file1 = "pt_subj1_encoding_scores.json"
pt_subj1_encoding_scores = {}
with open(file1, 'r') as f:
    pt_subj1_encoding_scores = json.load(f)

# %%
print(pt_subj1_decoding_scores.keys())
# Out:
# dict_keys(['decoding prompt-tuned-summarization with subj1_lang', 'decoding prompt-tuned-summarization with subj1_vis', 'decoding prompt-tuned-summarization with subj1_dmn', 'decoding prompt-tuned-summarization with subj1_task', 'decoding prompt-tuned-question-answering with subj1_lang', 'decoding prompt-tuned-question-answering with subj1_vis', 'decoding prompt-tuned-question-answering with subj1_dmn', 'decoding prompt-tuned-question-answering with subj1_task', 'decoding prompt-tuned-translation with subj1_lang', 'decoding prompt-tuned-translation with subj1_vis', 'decoding prompt-tuned-translation with subj1_dmn', 'decoding prompt-tuned-translation with subj1_task'])

# %% [markdown]
# # TASK ROI

# %%
import matplotlib.pyplot as plt
def plot_with_annotations(labels, scores, plot_title):
    plt.bar(labels, scores)
    plt.title(plot_title)
    for i, score in enumerate(scores):
        plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
    plt.show()
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
# plot the scores on the bars
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# %%
# import plt
import matplotlib.pyplot as plt
pt_subj1_decoding_scores 
print(ft_subj1_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_task']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_task']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
qa_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_task']
trans_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_task']
summ_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_task']
trans_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_task']
summ_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj1_encoding_scores 
print(ft_subj1_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_task']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_task']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_task']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_task']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj1_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_task']
qa_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_task']
trans_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_task']
summ_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_task']
trans_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_task']
summ_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_task']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

                            


                           # import plt
import matplotlib.pyplot as plt
pt_subj2_decoding_scores 
print(ft_subj2_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_task']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj2_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_task']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj2_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_task']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_task']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj2_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_task']
qa_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_task']
trans_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_task']
summ_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_task']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_task']
trans_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_task']
summ_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_task']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj2_encoding_scores 
print(ft_subj2_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_task']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_task']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj2_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_task']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_task']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj2_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_task']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_task']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj2_task"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.title(plot_title)
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_task']
qa_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_task']
trans_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_task']
summ_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_task']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_task']
trans_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_task']
summ_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_task']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_task"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['decoding prompt-tuned-summarization with subj1_lang', 'decoding prompt-tuned-summarization with subj1_vis', 'decoding prompt-tuned-summarization with subj1_dmn', 'decoding prompt-tuned-summarization with subj1_task', 'decoding prompt-tuned-question-answering with subj1_lang', 'decoding prompt-tuned-question-answering with subj1_vis', 'decoding prompt-tuned-question-answering with subj1_dmn', 'decoding prompt-tuned-question-answering with subj1_task', 'decoding prompt-tuned-translation with subj1_lang', 'decoding prompt-tuned-translation with subj1_vis', 'decoding prompt-tuned-translation with subj1_dmn', 'decoding prompt-tuned-translation with subj1_task'])
# ...

# %% [markdown]
# # LANG ROI

# %%
# import plt
import matplotlib.pyplot as plt
pt_subj1_decoding_scores 
print(ft_subj1_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_lang']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_lang']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj1_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_lang']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_lang']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj1_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_lang']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_lang']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj1_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_lang']
qa_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_lang']
trans_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_lang']
summ_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_lang']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_lang']
trans_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_lang']
summ_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_lang']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj1_encoding_scores 
print(ft_subj1_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_lang']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_lang']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj1_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_lang']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_lang']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj1_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_lang']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_lang']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj1_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_lang']
qa_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_lang']
trans_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_lang']
summ_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_lang']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_lang']
trans_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_lang']
summ_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_lang']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

                            


                           # import plt
import matplotlib.pyplot as plt
pt_subj2_decoding_scores 
print(ft_subj2_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_lang']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_lang']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj2_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_lang']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_lang']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj2_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_lang']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_lang']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj2_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_lang']
qa_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_lang']
trans_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_lang']
summ_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_lang']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_lang']
trans_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_lang']
summ_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_lang']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj2_encoding_scores 
print(ft_subj2_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_lang']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_lang']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj2_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_lang']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_lang']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj2_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_lang']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_lang']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj2_lang"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.title(plot_title)
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_lang']
qa_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_lang']
trans_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_lang']
summ_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_lang']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_lang']
trans_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_lang']
summ_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_lang']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_lang"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['decoding prompt-tuned-summarization with subj1_lang', 'decoding prompt-tuned-summarization with subj1_vis', 'decoding prompt-tuned-summarization with subj1_dmn', 'decoding prompt-tuned-summarization with subj1_task', 'decoding prompt-tuned-question-answering with subj1_lang', 'decoding prompt-tuned-question-answering with subj1_vis', 'decoding prompt-tuned-question-answering with subj1_dmn', 'decoding prompt-tuned-question-answering with subj1_task', 'decoding prompt-tuned-translation with subj1_lang', 'decoding prompt-tuned-translation with subj1_vis', 'decoding prompt-tuned-translation with subj1_dmn', 'decoding prompt-tuned-translation with subj1_task'])
# ...

# %% [markdown]
# # VIS ROI

# %%
# import plt
import matplotlib.pyplot as plt
pt_subj1_decoding_scores 
print(ft_subj1_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_vis']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_vis']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj1_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_vis']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_vis']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj1_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_vis']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_vis']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj1_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_vis']
qa_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_vis']
trans_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_vis']
summ_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_vis']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_vis']
trans_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_vis']
summ_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_vis']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj1_encoding_scores 
print(ft_subj1_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_vis']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_vis']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj1_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_vis']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_vis']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj1_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_vis']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_vis']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj1_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_vis']
qa_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_vis']
trans_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_vis']
summ_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_vis']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_vis']
trans_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_vis']
summ_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_vis']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

                            


                           # import plt
import matplotlib.pyplot as plt
pt_subj2_decoding_scores 
print(ft_subj2_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_vis']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_vis']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj2_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_vis']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_vis']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj2_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_vis']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_vis']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj2_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_vis']
qa_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_vis']
trans_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_vis']
summ_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_vis']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_vis']
trans_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_vis']
summ_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_vis']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj2_encoding_scores 
print(ft_subj2_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_vis']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_vis']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj2_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_vis']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_vis']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj2_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_vis']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_vis']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj2_vis"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.title(plot_title)
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_vis']
qa_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_vis']
trans_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_vis']
summ_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_vis']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_vis']
trans_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_vis']
summ_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_vis']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_vis"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['decoding prompt-tuned-summarization with subj1_lang', 'decoding prompt-tuned-summarization with subj1_vis', 'decoding prompt-tuned-summarization with subj1_dmn', 'decoding prompt-tuned-summarization with subj1_task', 'decoding prompt-tuned-question-answering with subj1_lang', 'decoding prompt-tuned-question-answering with subj1_vis', 'decoding prompt-tuned-question-answering with subj1_dmn', 'decoding prompt-tuned-question-answering with subj1_task', 'decoding prompt-tuned-translation with subj1_lang', 'decoding prompt-tuned-translation with subj1_vis', 'decoding prompt-tuned-translation with subj1_dmn', 'decoding prompt-tuned-translation with subj1_task'])
# ...

# %% [markdown]
# # DNM ROI

# %%
# import plt
import matplotlib.pyplot as plt
pt_subj1_decoding_scores 
print(ft_subj1_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_dmn']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj1_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_dmn']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj1_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_dmn']
ft_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj1_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_dmn']
qa_score = ft_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_dmn']
trans_score = ft_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_dmn']
summ_score = ft_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_dmn']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')

plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_decoding_scores['decoding prompt-tuned-question-answering with subj1_dmn']
trans_score = pt_subj1_decoding_scores['decoding prompt-tuned-translation with subj1_dmn']
summ_score = pt_subj1_decoding_scores['decoding prompt-tuned-summarization with subj1_dmn']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj1_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj1_encoding_scores 
print(ft_subj1_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_dmn']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj1_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_dmn']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj1_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_dmn']
ft_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj1_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_dmn']
qa_score = ft_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_dmn']
trans_score = ft_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_dmn']
summ_score = ft_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_dmn']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj1_encoding_scores['encoding prompt-tuned-question-answering with subj1_dmn']
trans_score = pt_subj1_encoding_scores['encoding prompt-tuned-translation with subj1_dmn']
summ_score = pt_subj1_encoding_scores['encoding prompt-tuned-summarization with subj1_dmn']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj1_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

                            


                           # import plt
import matplotlib.pyplot as plt
pt_subj2_decoding_scores 
print(ft_subj2_decoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_dmn']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for summarization with subj2_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_dmn']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for translation with subj2_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_dmn']
ft_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for question-answering with subj2_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_dmn']
qa_score = ft_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_dmn']
trans_score = ft_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_dmn']
summ_score = ft_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_dmn']
plot_title = "Comparing fine-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_decoding_scores['decoding prompt-tuned-question-answering with subj2_dmn']
trans_score = pt_subj2_decoding_scores['decoding prompt-tuned-translation with subj2_dmn']
summ_score = pt_subj2_decoding_scores['decoding prompt-tuned-summarization with subj2_dmn']
plot_title = "Comparing prompt-tuned decoding Accuracy for summarization, translation, and question-answering with subj2_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# import plt
import matplotlib.pyplot as plt
pt_subj2_encoding_scores 
print(ft_subj2_encoding_scores.keys())
labels = ['prompt_tuned', 'fine_tuned']
# for summarization
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_dmn']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for summarization with subj2_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_dmn']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for translation with subj2_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_dmn']
ft_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_dmn']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for question-answering with subj2_dmn"
plt.bar(labels, [pt_score['Accuracy'], ft_score['Accuracy']])
for i, score in enumerate([pt_score['Accuracy'], ft_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.title(plot_title)
plt.show()
# summ vs trans vs qa in fineutning
labels = ['summarization', 'translation', 'question-answering']
pt_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_dmn']
qa_score = ft_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_dmn']
trans_score = ft_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_dmn']
summ_score = ft_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_dmn']
plot_title = "Comparing fine-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

labels = ['summarization', 'translation', 'question-answering']
qa_score = pt_subj2_encoding_scores['encoding prompt-tuned-question-answering with subj2_dmn']
trans_score = pt_subj2_encoding_scores['encoding prompt-tuned-translation with subj2_dmn']
summ_score = pt_subj2_encoding_scores['encoding prompt-tuned-summarization with subj2_dmn']
plot_title = "Comparing prompt-tuned encoding Accuracy for summarization, translation, and question-answering with subj2_dmn"
plt.bar(labels, [summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']])
plt.title(plot_title)
for i, score in enumerate([summ_score['Accuracy'], trans_score['Accuracy'], qa_score['Accuracy']]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['decoding prompt-tuned-summarization with subj1_lang', 'decoding prompt-tuned-summarization with subj1_vis', 'decoding prompt-tuned-summarization with subj1_dmn', 'decoding prompt-tuned-summarization with subj1_task', 'decoding prompt-tuned-question-answering with subj1_lang', 'decoding prompt-tuned-question-answering with subj1_vis', 'decoding prompt-tuned-question-answering with subj1_dmn', 'decoding prompt-tuned-question-answering with subj1_task', 'decoding prompt-tuned-translation with subj1_lang', 'decoding prompt-tuned-translation with subj1_vis', 'decoding prompt-tuned-translation with subj1_dmn', 'decoding prompt-tuned-translation with subj1_task'])
# ...
