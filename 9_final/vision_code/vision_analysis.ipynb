# %%
import numpy as np

# %%
import os
print(os.getcwd())
# move to parent_dir
os.chdir(os.path.dirname(os.getcwd()))
print(os.getcwd())
# Out:
# /home2/advaith.malladi/csai_a4
# /home2/advaith.malladi

# %%
# chdir to csai_a5/scores
os.chdir('csai_a5/scores')
print(os.getcwd())
# Out:
# /home2/advaith.malladi/csai_a5/scores

# %%
decoding_ft_vis = {}
filename = './vision/decoding_ft_vis.json'
# load filename into decoding_ft_vis
import json
with open(filename) as json_file:
    decoding_ft_vis = json.load(json_file)
decoding_pt_vis = {}
filename = './vision/decoding_pt_vis.json'
# load filename into decoding_pt_vis
with open(filename) as json_file:
    decoding_pt_vis = json.load(json_file)
encoding_ft_vis = {}
filename = './vision/encoding_ft_vis.json'
# load filename into encoding_ft_vis
with open(filename) as json_file:
    encoding_ft_vis = json.load(json_file)
encoding_pt_vis = {}
filename = './vision/encoding_pt_vis.json'
# load filename into encoding_pt_vis
with open(filename) as json_file:
    encoding_pt_vis = json.load(json_file)

# %%
print(decoding_ft_vis.keys())
print(decoding_pt_vis.keys())
print(encoding_ft_vis.keys())
print(encoding_pt_vis.keys())
# Out:
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])
# ...

# %% [markdown]
# # For LOC ROI

# %%
#decoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for mnist with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for cifar with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = decoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = decoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
#encoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
print(encoding_ft_vis.keys())
fine_tuned_score = encoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for mnist with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = encoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for cifar with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = encoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = encoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])

# %% [markdown]
# # OPA ROI

# %%
#decoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding mnist using OPA']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding mnist using OPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for mnist with OPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding cifar using OPA']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding cifar using OPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for cifar with OPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_ft_vis['Decoding mnist using OPA']['Accuracy']
cifar_score = decoding_ft_vis['Decoding cifar using OPA']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with OPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_pt_vis['Decoding mnist using OPA']['Accuracy']
cifar_score = decoding_pt_vis['Decoding cifar using OPA']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with OPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
#encoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
print(encoding_ft_vis.keys())
fine_tuned_score = encoding_ft_vis['Decoding mnist using OPA']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding mnist using OPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for mnist with OPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = encoding_ft_vis['Decoding cifar using OPA']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding cifar using OPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for cifar with OPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_ft_vis['Decoding mnist using OPA']['Accuracy']
cifar_score = encoding_ft_vis['Decoding cifar using OPA']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with OPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_pt_vis['Decoding mnist using OPA']['Accuracy']
cifar_score = encoding_pt_vis['Decoding cifar using OPA']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with OPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])

# %% [markdown]
# # PPA ROI

# %%
#decoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding mnist using PPA']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding mnist using PPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for mnist with PPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding cifar using PPA']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding cifar using PPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for cifar with PPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_ft_vis['Decoding mnist using PPA']['Accuracy']
cifar_score = decoding_ft_vis['Decoding cifar using PPA']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with PPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_pt_vis['Decoding mnist using PPA']['Accuracy']
cifar_score = decoding_pt_vis['Decoding cifar using PPA']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with PPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
#encoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
print(encoding_ft_vis.keys())
fine_tuned_score = encoding_ft_vis['Decoding mnist using PPA']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding mnist using PPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for mnist with PPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = encoding_ft_vis['Decoding cifar using PPA']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding cifar using PPA']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for cifar with PPA"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_ft_vis['Decoding mnist using PPA']['Accuracy']
cifar_score = encoding_ft_vis['Decoding cifar using PPA']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with PPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_pt_vis['Decoding mnist using PPA']['Accuracy']
cifar_score = encoding_pt_vis['Decoding cifar using PPA']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with PPA"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])

# %% [markdown]
# # RSC ROI

# %%
#decoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding mnist using RSC']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding mnist using RSC']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for mnist with RSC"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding cifar using RSC']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding cifar using RSC']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for cifar with RSC"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_ft_vis['Decoding mnist using RSC']['Accuracy']
cifar_score = decoding_ft_vis['Decoding cifar using RSC']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with RSC"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_pt_vis['Decoding mnist using RSC']['Accuracy']
cifar_score = decoding_pt_vis['Decoding cifar using RSC']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with RSC"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
#encoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
print(encoding_ft_vis.keys())
fine_tuned_score = encoding_ft_vis['Decoding mnist using RSC']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding mnist using RSC']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for mnist with RSC"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = encoding_ft_vis['Decoding cifar using RSC']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding cifar using RSC']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for cifar with RSC"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_ft_vis['Decoding mnist using RSC']['Accuracy']
cifar_score = encoding_ft_vis['Decoding cifar using RSC']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with RSC"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_pt_vis['Decoding mnist using RSC']['Accuracy']
cifar_score = encoding_pt_vis['Decoding cifar using RSC']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with RSC"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])

# %% [markdown]
# # EarlyVis ROI

# %%
#decoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for mnist with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = decoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
promp_tuned_score = decoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned decoding Accuracy for cifar with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = decoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = decoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = decoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar decoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
#encoding
# for mnist
import matplotlib.pyplot as plt
labels = ['promp tuned', 'fine tuned']
print(encoding_ft_vis.keys())
fine_tuned_score = encoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for mnist with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
labels = ['promp tuned', 'fine tuned']
fine_tuned_score = encoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
promp_tuned_score = encoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing fine-tuned and prompt-tuned encoding Accuracy for cifar with EarlyVis"
plt.bar(labels, [promp_tuned_score, fine_tuned_score])
plt.title(plot_title)
for i, score in enumerate([promp_tuned_score, fine_tuned_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# finetuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_ft_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = encoding_ft_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# prompttuned mnist vs cifar
labels = ['mnist', 'cifar']
mnist_score = encoding_pt_vis['Decoding mnist using EarlyVis']['Accuracy']
cifar_score = encoding_pt_vis['Decoding cifar using EarlyVis']['Accuracy']
plot_title = "Comparing mnist and cifar encoding Accuracy with EarlyVis"
plt.bar(labels, [mnist_score, cifar_score])
plt.title(plot_title)
for i, score in enumerate([mnist_score, cifar_score]):
    plt.text(i, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()
# Out:
# dict_keys(['Decoding mnist using LOC', 'Decoding mnist using OPA', 'Decoding mnist using PPA', 'Decoding mnist using RSC', 'Decoding mnist using EarlyVis', 'Decoding cifar using LOC', 'Decoding cifar using OPA', 'Decoding cifar using PPA', 'Decoding cifar using RSC', 'Decoding cifar using EarlyVis'])
